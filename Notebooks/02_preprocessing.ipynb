# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("D:\\VNSGU_PDA_DATA\\Data-Analytics-using-Python-Minor-Project\\Data\\raw\\VNSGU_Results.xlsx")

# %%
columns_to_drop = ['NETWORK_TECHNOLOGY_Ext_Theory', 'NETWORK_TECHNOLOGY_Ext_Practical','NETWORK_TECHNOLOGY_Int_Theory',
       'NETWORK_TECHNOLOGY_Int_Practical', 'Course_Ext_Theory',
        'Course_Ext_Practical', 'Course_Int_Theory',
        'Course_Int_Practical'] 
  
cleaned_file_path = (
    "D:\\VNSGU_PDA_DATA\\Data-Analytics-using-Python-Minor-Project\\Data\\processed\\cleaned_student_data.xlsx"
)

df.drop(columns=columns_to_drop, inplace=True, errors="ignore")


df.to_excel(cleaned_file_path, index=False)

# %%
len(df.columns)
# Out:
# 41

# %%
df.isna().sum()
# Out:
# Seat Number                                    0
# Name                                           0
# College Name                                   0
# Total Marks                                    0
# SGPA                                           0
# Result                                         0
# Course_Name                                    0
# ADVANCE_WEB_TECHNOLOGY_Ext_Theory             37
# ADVANCE_WEB_TECHNOLOGY_Ext_Practical         182
# ADVANCE_WEB_TECHNOLOGY_Total_Ext             194
# ADVANCE_WEB_TECHNOLOGY_Int_Theory              0
# ADVANCE_WEB_TECHNOLOGY_Int_Practical          45
# ADVANCE_WEB_TECHNOLOGY_Total_Int              45
# ADVANCE_WEB_TECHNOLOGY_Total_Obt               0
# WEB_FRAMEWORK_AND_SERVICES_Ext_Theory         39
# WEB_FRAMEWORK_AND_SERVICES_Ext_Practical     157
# WEB_FRAMEWORK_AND_SERVICES_Total_Ext         168
# WEB_FRAMEWORK_AND_SERVICES_Int_Theory          1
# WEB_FRAMEWORK_AND_SERVICES_Int_Practical      47
# WEB_FRAMEWORK_AND_SERVICES_Total_Int          47
# WEB_FRAMEWORK_AND_SERVICES_Total_Obt           1
# .NET_TECHNOLOGY_Ext_Theory                    39
# .NET_TECHNOLOGY_Ext_Practical                103
# .NET_TECHNOLOGY_Total_Ext                    113
# .NET_TECHNOLOGY_Int_Theory                     1
# .NET_TECHNOLOGY_Int_Practical                 11
# .NET_TECHNOLOGY_Total_Int                     11
# .NET_TECHNOLOGY_Total_Obt                      1
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Theory        43
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Practical    105
# LINUX_OPERATING_SYSTEM(LOS)_Total_Ext        117
# LINUX_OPERATING_SYSTEM(LOS)_Int_Theory         1
# LINUX_OPERATING_SYSTEM(LOS)_Int_Practical      8
# LINUX_OPERATING_SYSTEM(LOS)_Total_Int          9
# LINUX_OPERATING_SYSTEM(LOS)_Total_Obt          9
# NETWORK_TECHNOLOGY_Total_Ext                 334
# NETWORK_TECHNOLOGY_Total_Int                   1
# NETWORK_TECHNOLOGY_Total_Obt                  49
# Course_Total_Ext                              31
# Course_Total_Int                               0
# Course_Total_Obt                               1
# dtype: int64

# %%
columns_to_fill = [
    'ADVANCE_WEB_TECHNOLOGY_Ext_Theory',
    'ADVANCE_WEB_TECHNOLOGY_Ext_Practical',
    'ADVANCE_WEB_TECHNOLOGY_Total_Ext',
    'ADVANCE_WEB_TECHNOLOGY_Int_Theory',
    'ADVANCE_WEB_TECHNOLOGY_Int_Practical',
    'ADVANCE_WEB_TECHNOLOGY_Total_Int',
    'ADVANCE_WEB_TECHNOLOGY_Total_Obt',
    'WEB_FRAMEWORK_AND_SERVICES_Ext_Theory',
    'WEB_FRAMEWORK_AND_SERVICES_Ext_Practical',
    'WEB_FRAMEWORK_AND_SERVICES_Total_Ext',
    'WEB_FRAMEWORK_AND_SERVICES_Int_Theory',
    'WEB_FRAMEWORK_AND_SERVICES_Int_Practical',
    'WEB_FRAMEWORK_AND_SERVICES_Total_Int',
    'WEB_FRAMEWORK_AND_SERVICES_Total_Obt',
    '.NET_TECHNOLOGY_Ext_Theory',
    '.NET_TECHNOLOGY_Ext_Practical',
    '.NET_TECHNOLOGY_Total_Ext',
    '.NET_TECHNOLOGY_Int_Theory',
    '.NET_TECHNOLOGY_Int_Practical',
    '.NET_TECHNOLOGY_Total_Int',
    '.NET_TECHNOLOGY_Total_Obt',
    'LINUX_OPERATING_SYSTEM(LOS)_Ext_Theory',
    'LINUX_OPERATING_SYSTEM(LOS)_Ext_Practical',
    'LINUX_OPERATING_SYSTEM(LOS)_Total_Ext',
    'LINUX_OPERATING_SYSTEM(LOS)_Int_Theory',
    'LINUX_OPERATING_SYSTEM(LOS)_Int_Practical',
    'LINUX_OPERATING_SYSTEM(LOS)_Total_Int',
    'LINUX_OPERATING_SYSTEM(LOS)_Total_Obt',
    'NETWORK_TECHNOLOGY_Total_Ext',
    'NETWORK_TECHNOLOGY_Total_Int',
    'NETWORK_TECHNOLOGY_Total_Obt',
    'Course_Total_Ext',
    'Course_Total_Int',
    'Course_Total_Obt'
]
df[columns_to_fill] = df[columns_to_fill].fillna(0)
df.to_excel(cleaned_file_path, index=False)

# %%
df.isna().sum()
# Out:
# Seat Number                                  0
# Name                                         0
# College Name                                 0
# Total Marks                                  0
# SGPA                                         0
# Result                                       0
# Course_Name                                  0
# ADVANCE_WEB_TECHNOLOGY_Ext_Theory            0
# ADVANCE_WEB_TECHNOLOGY_Ext_Practical         0
# ADVANCE_WEB_TECHNOLOGY_Total_Ext             0
# ADVANCE_WEB_TECHNOLOGY_Int_Theory            0
# ADVANCE_WEB_TECHNOLOGY_Int_Practical         0
# ADVANCE_WEB_TECHNOLOGY_Total_Int             0
# ADVANCE_WEB_TECHNOLOGY_Total_Obt             0
# WEB_FRAMEWORK_AND_SERVICES_Ext_Theory        0
# WEB_FRAMEWORK_AND_SERVICES_Ext_Practical     0
# WEB_FRAMEWORK_AND_SERVICES_Total_Ext         0
# WEB_FRAMEWORK_AND_SERVICES_Int_Theory        0
# WEB_FRAMEWORK_AND_SERVICES_Int_Practical     0
# WEB_FRAMEWORK_AND_SERVICES_Total_Int         0
# WEB_FRAMEWORK_AND_SERVICES_Total_Obt         0
# .NET_TECHNOLOGY_Ext_Theory                   0
# .NET_TECHNOLOGY_Ext_Practical                0
# .NET_TECHNOLOGY_Total_Ext                    0
# .NET_TECHNOLOGY_Int_Theory                   0
# .NET_TECHNOLOGY_Int_Practical                0
# .NET_TECHNOLOGY_Total_Int                    0
# .NET_TECHNOLOGY_Total_Obt                    0
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Theory       0
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Practical    0
# LINUX_OPERATING_SYSTEM(LOS)_Total_Ext        0
# LINUX_OPERATING_SYSTEM(LOS)_Int_Theory       0
# LINUX_OPERATING_SYSTEM(LOS)_Int_Practical    0
# LINUX_OPERATING_SYSTEM(LOS)_Total_Int        0
# LINUX_OPERATING_SYSTEM(LOS)_Total_Obt        0
# NETWORK_TECHNOLOGY_Total_Ext                 0
# NETWORK_TECHNOLOGY_Total_Int                 0
# NETWORK_TECHNOLOGY_Total_Obt                 0
# Course_Total_Ext                             0
# Course_Total_Int                             0
# Course_Total_Obt                             0
# dtype: int64

# %%
df['SGPA'] = df['SGPA'].replace('--', 0) 
df['SGPA'] = pd.to_numeric(df['SGPA'], errors='coerce').fillna(0)
df.to_excel(cleaned_file_path, index=False)

# %%
df['Total Marks'] = df['Total Marks'].astype(str).str.split('/').str[0].str.strip()
df['Total Marks'] = pd.to_numeric(df['Total Marks'], errors='coerce').fillna(0)
print(df['Total Marks'].head())
df['Total Marks'].dtype
df.to_excel(cleaned_file_path, index=False)
# Out:
# 0    332
# 1    347
# 2    348
# 3    347
# 4    325
# Name: Total Marks, dtype: int64

# %%
df.value_counts("Result")
# Out:
# Result
# PASS          8153
# PASS O.150     419
# FAIL           408
# PASS O.149       7
# Name: count, dtype: int64

# %%
df['Result'] = df['Result'].str.strip().replace({
    'PASS O.150': 'PASS',
    'PASS O.149': 'PASS'
})

df['Result'].value_counts()

df.to_excel(cleaned_file_path, index=False)

# %%
df.isna().sum()
# Out:
# Seat Number                                  0
# Name                                         0
# College Name                                 0
# Total Marks                                  0
# SGPA                                         0
# Result                                       0
# Course_Name                                  0
# ADVANCE_WEB_TECHNOLOGY_Ext_Theory            0
# ADVANCE_WEB_TECHNOLOGY_Ext_Practical         0
# ADVANCE_WEB_TECHNOLOGY_Total_Ext             0
# ADVANCE_WEB_TECHNOLOGY_Int_Theory            0
# ADVANCE_WEB_TECHNOLOGY_Int_Practical         0
# ADVANCE_WEB_TECHNOLOGY_Total_Int             0
# ADVANCE_WEB_TECHNOLOGY_Total_Obt             0
# WEB_FRAMEWORK_AND_SERVICES_Ext_Theory        0
# WEB_FRAMEWORK_AND_SERVICES_Ext_Practical     0
# WEB_FRAMEWORK_AND_SERVICES_Total_Ext         0
# WEB_FRAMEWORK_AND_SERVICES_Int_Theory        0
# WEB_FRAMEWORK_AND_SERVICES_Int_Practical     0
# WEB_FRAMEWORK_AND_SERVICES_Total_Int         0
# WEB_FRAMEWORK_AND_SERVICES_Total_Obt         0
# .NET_TECHNOLOGY_Ext_Theory                   0
# .NET_TECHNOLOGY_Ext_Practical                0
# .NET_TECHNOLOGY_Total_Ext                    0
# .NET_TECHNOLOGY_Int_Theory                   0
# .NET_TECHNOLOGY_Int_Practical                0
# .NET_TECHNOLOGY_Total_Int                    0
# .NET_TECHNOLOGY_Total_Obt                    0
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Theory       0
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Practical    0
# LINUX_OPERATING_SYSTEM(LOS)_Total_Ext        0
# LINUX_OPERATING_SYSTEM(LOS)_Int_Theory       0
# LINUX_OPERATING_SYSTEM(LOS)_Int_Practical    0
# LINUX_OPERATING_SYSTEM(LOS)_Total_Int        0
# LINUX_OPERATING_SYSTEM(LOS)_Total_Obt        0
# NETWORK_TECHNOLOGY_Total_Ext                 0
# NETWORK_TECHNOLOGY_Total_Int                 0
# NETWORK_TECHNOLOGY_Total_Obt                 0
# Course_Total_Ext                             0
# Course_Total_Int                             0
# Course_Total_Obt                             0
# dtype: int64

# %%
rename_map = {
    'ADVANCE_WEB_TECHNOLOGY_Ext_Theory': 'AWD_Ext_Th',
    'ADVANCE_WEB_TECHNOLOGY_Ext_Practical': 'AWD_Ext_Pr',
    'ADVANCE_WEB_TECHNOLOGY_Total_Ext': 'AWD_Ext_Total',
    'ADVANCE_WEB_TECHNOLOGY_Int_Theory': 'AWD_Int_Th',
    'ADVANCE_WEB_TECHNOLOGY_Int_Practical': 'AWD_Int_Pr',
    'ADVANCE_WEB_TECHNOLOGY_Total_Int': 'AWD_Int_Total',
    'ADVANCE_WEB_TECHNOLOGY_Total_Obt': 'AWD_Total',

    'WEB_FRAMEWORK_AND_SERVICES_Ext_Theory': 'WFS_Ext_Th',
    'WEB_FRAMEWORK_AND_SERVICES_Ext_Practical': 'WFS_Ext_Pr',
    'WEB_FRAMEWORK_AND_SERVICES_Total_Ext': 'WFS_Ext_Total',
    'WEB_FRAMEWORK_AND_SERVICES_Int_Theory': 'WFS_Int_Th',
    'WEB_FRAMEWORK_AND_SERVICES_Int_Practical': 'WFS_Int_Pr',
    'WEB_FRAMEWORK_AND_SERVICES_Total_Int': 'WFS_Int_Total',
    'WEB_FRAMEWORK_AND_SERVICES_Total_Obt': 'WFS_Total',

    '.NET_TECHNOLOGY_Ext_Theory': '.NET_Ext_Th',
    '.NET_TECHNOLOGY_Ext_Practical': '.NET_Ext_Pr',
    '.NET_TECHNOLOGY_Total_Ext': '.NET_Ext_Total',
    '.NET_TECHNOLOGY_Int_Theory': '.NET_Int_Th',
    '.NET_TECHNOLOGY_Int_Practical': '.NET_Int_Pr',
    '.NET_TECHNOLOGY_Total_Int': '.NET_Int_Total',
    '.NET_TECHNOLOGY_Total_Obt': '.NET_Total',

    'LINUX_OPERATING_SYSTEM(LOS)_Ext_Theory': 'LOS_Ext_Th',
    'LINUX_OPERATING_SYSTEM(LOS)_Ext_Practical': 'LOS_Ext_Pr',
    'LINUX_OPERATING_SYSTEM(LOS)_Total_Ext': 'LOS_Ext_Total',
    'LINUX_OPERATING_SYSTEM(LOS)_Int_Theory': 'LOS_Int_Th',
    'LINUX_OPERATING_SYSTEM(LOS)_Int_Practical': 'LOS_Int_Pr',
    'LINUX_OPERATING_SYSTEM(LOS)_Total_Int': 'LOS_Int_Total',
    'LINUX_OPERATING_SYSTEM(LOS)_Total_Obt': 'LOS_Total',

    'NETWORK_TECHNOLOGY_Total_Ext': 'NT_Ext_Total',
    'NETWORK_TECHNOLOGY_Total_Int': 'NT_Int_Total',
    'NETWORK_TECHNOLOGY_Total_Obt': 'NT_Total',

    'Course_Total_Ext': 'CC_Ext_Total',
    'Course_Total_Int': 'CC_Int_Total',
    'Course_Total_Obt': 'CC_Total'
}
df.rename(columns=rename_map, inplace=True)
df.to_excel(cleaned_file_path, index=False)

# %%
df.dtypes
# Out:
# Seat Number         int64
# Name               object
# College Name       object
# Total Marks         int64
# SGPA              float64
# Result             object
# Course_Name        object
# AWD_Ext_Th        float64
# AWD_Ext_Pr        float64
# AWD_Ext_Total     float64
# AWD_Int_Th          int64
# AWD_Int_Pr        float64
# AWD_Int_Total     float64
# AWD_Total           int64
# WFS_Ext_Th        float64
# WFS_Ext_Pr        float64
# WFS_Ext_Total     float64
# WFS_Int_Th        float64
# WFS_Int_Pr        float64
# WFS_Int_Total     float64
# WFS_Total         float64
# .NET_Ext_Th       float64
# .NET_Ext_Pr       float64
# .NET_Ext_Total    float64
# .NET_Int_Th       float64
# .NET_Int_Pr       float64
# .NET_Int_Total    float64
# .NET_Total        float64
# LOS_Ext_Th        float64
# LOS_Ext_Pr        float64
# LOS_Ext_Total     float64
# LOS_Int_Th        float64
# LOS_Int_Pr        float64
# LOS_Int_Total     float64
# LOS_Total         float64
# NT_Ext_Total      float64
# NT_Int_Total      float64
# NT_Total          float64
# CC_Ext_Total      float64
# CC_Int_Total        int64
# CC_Total          float64
# dtype: object

# %%
marks_columns = [
    'AWD_Ext_Th', 'AWD_Ext_Pr', 'AWD_Ext_Total',
    'AWD_Int_Th', 'AWD_Int_Pr', 'AWD_Int_Total', 'AWD_Total',
    'WFS_Ext_Th', 'WFS_Ext_Pr', 'WFS_Ext_Total',
    'WFS_Int_Th', 'WFS_Int_Pr', 'WFS_Int_Total', 'WFS_Total',
    '.NET_Ext_Th', '.NET_Ext_Pr', '.NET_Ext_Total',
    '.NET_Int_Th', '.NET_Int_Pr', '.NET_Int_Total', '.NET_Total',
    'LOS_Ext_Th', 'LOS_Ext_Pr', 'LOS_Ext_Total',
    'LOS_Int_Th', 'LOS_Int_Pr', 'LOS_Int_Total', 'LOS_Total',
    'NT_Ext_Total', 'NT_Int_Total', 'NT_Total',
    'CC_Ext_Total', 'CC_Int_Total', 'CC_Total'
]
df[marks_columns] = (
    df[marks_columns]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .astype(int)
)
df.to_excel(cleaned_file_path, index=False)

# %%
df['Percentage'] = (df['Total Marks'] / 550) * 100
df.to_excel(cleaned_file_path, index=False)

# %%
# Define the incorrect long campus name
old_name = "PROF. V.B. SHAH INSTITUTE OF MANAGEMENT & R.V. PATEL COLLEGE OF COMMERCE (ENG. MED.), V.L. SHAH COLLEGE OF COMMERCE (GUJ. MED.), SUTEX BANK COLLEGE OF COMPUTER APPLICATION & SCIENCE, AMROLI, SURAT"

# Define the correct name
new_name = "SUTEX BANK COLLEGE OF COMPUTER APPLICATION & SCIENCE, AMROLI, SURAT"

# Replace in dataset
df['College Name'] = df['College Name'].replace(old_name, new_name)

# Verify change
print(df['College Name'].unique())

# Save updated file
df.to_excel(cleaned_file_path, index=False)
# Out:
# ['V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA'
#  'SMT. R.P. CHAUHAN ARTS & SMT. J.K. SHAH & SHRI K.D. SHAH COMMERCE COLLEGE, VYARA'
#  'NARMADA COLLEGE OF SCIENCE & COMMERCE, ZADESHWAR'
#  'K. B. SUMERIA COMMERCE & NATARAJ PROFESSIONAL SCIENCE COLLEGE, VAPI'
#  'DOLAT USHA INSTITUTE OF APPLIED SCIENCES & DHIRU-SARLA INSTITUTE OF MANAGEMENT & COMMERCE, VALSAD'
#  'NARANLALA COLLEGE OF PROFESSIONAL & APPLIED SCIENCES, NAVSARI'
#  'COLLEGE OF APPLIED SCIENCES AND PROFESSIONAL STUDIES, CHIKHLI'
#  'R.K. DESAI ACHCHHARIWALA COLLEGE OF COMPUTER & APPLIED SCIENCES, VAPI'
#  'M.K. INSTITUTE OF COMPUTER STUDIES, BHARUCH'
#  'SMT. TANUBEN & DR. MANUBHAI TRIVEDI COLLEGE OF INFORMATION SCIENCE, SURAT (WADIA BCA)'
#  'C.B. PATEL COMPUTER COLLEGE & JAMANABEN NARROTTAMBHAI MOTIRAM PATEL SCIENCE COLLEGE, BHARTHANA, VESU, SURAT.'
#  'VIVEKANAND COLLEGE FOR ADVANCED COMPUTER & INFORMATION SCIENCE, SURAT'
#  'AMBABA COMMERCE COLLEGE, MANIBA INSTITUTE OF BUSINESS MANAGEMENT & DEVIBA INSTITUTE OF COMPUTER APPLICATION, SABARGAM, SURAT'
#  'VIMAL TORMAL PODDAR BCA COLLEGE,PANDESARA, SURAT.'
#  'SHRI MANILAL KADAKIA COLLEGE OF COMMERCE, MANAGEMENT, SCIENCE & COMPUTER STUDIES, ANKLESHWAR'
#  'UDHNA CITIZEN COMMERCE COLLEGE & S.P.B. COLLEGE OF BUSINESS ADMINISTRATION & SMT. DIWALIBEN HARJIBHAI GONDALIYA COLLEGE OF BCA & IT, SURAT'
#  'SHRI SHAMBHUBHAI V. PATEL COLLEGE OF COMPUTER SCIENCE & BUSINESS MANAGEMENT,SURAT'
#  'DOLLYBEN DESAI INSTITUTE OF COMPUTER & APPLIED SCIENCE, PALSANA, SURAT'
#  'SHREE UTTAR GUJARAT BCA COLLEGE, SURAT'
#  'SMT. Z.S. PATEL COLLEGE OF MANAGEMENT & TECHNOLOGY, SURAT'
#  'S.S. AGRAWAL COLLEGE OF COMMERCE & MANAGEMENT, NAVSARI'
#  'M.L.PARMAR COLLEGE OF COMPUTER SCIENCE & I.T.,SURAT'
#  'SUTEX BANK COLLEGE OF COMPUTER APPLICATION & SCIENCE, AMROLI, SURAT'
#  'IQRA BCA COLLEGE, BHARUCH' 'SDJ INTERNATIONAL COLLEGE, VESU, SURAT'
#  'SHRINATHJI COLLEGE OF COMPUTER APPLICATION, DAMAN'
#  'SASCMA ENGLISH MEDIUM COMMERCE COLLEGE & SHRI HASMUKHLAL HOJIWALA COLLEGE OF BUSINESS ADMINISTRATION(BBA) & SMT. USHABEN JAYVADAN BODAWALA COLLEGE OF COMPUTER APPLICATION (BCA) VESU SURAT'
#  'PRABHU B.C.A. COLLEGE,UMRA, SURAT'
#  'ATMANAND SARASWATI SCIENCE COLLEGE, VARACHHA, SURAT'
#  'SDJ INTERNATIONAL COLLEGE, PALSANA'
#  'VISHWABHARTI GIRLS INSTITUTE OF COMMERCE, MANAGEMENT AND COMPUTER APPLICATION, MORTHANA'
#  'THE MANDVI EDUCATION SOCIETY BBA, BCA AND SCIENCE COLLEGE, MANDVI'
#  'VIDYABHARTI TRUST COLLEGE OF BUSINESS, COMPUTER SCIENCE AND RESEARCH, UMRAKH, BARDOLI'
#  'C.K.PITHAWALLA COLLEGE OF COMMERCE-MANAGEMENT-COMPUTER APPLICATION,DUMAS ROAD, SURAT'
#  'SMT.RANIBEN MADHABHAI BHADARKA B.C.A. COLLEGE, PALSANA, SURAT'
#  'PRIME INSTITUTE OF COMPUTER & MANAGEMENT MAROLI-UBHARAT ROAD, DIST NAVSARI-396436']
