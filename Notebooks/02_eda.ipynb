# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("D:\\VNSGU_PDA_DATA\\Data-Analytics-using-Python-Minor-Project\\Data\\raw\\VNSGU_Results.xlsx")

# %%
df.head()
# Out:
#    Seat Number                        Name  \
# 0         1001  ADEP SAIKRISHNA KISHORBHAI
# 1         1002      AHIR KRISH PRAMODKUMAR
# 2         1003       AHIR MEET MANSUKHBHAI
# 3         1004    AHIR MITKUMAR SURESHBHAI
# 4         1005       AHIR NILAY ARVINDBHAI
#
#                                      College Name Total Marks  SGPA Result  \
# 0  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA   332 / 550  6.18   PASS
# 1  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA   347 / 550  6.36   PASS
# 2  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA   348 / 550  6.18   PASS
# 3  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA   347 / 550  6.36   PASS
# 4  V.S. PATEL COLLEGE OF ARTS & SCIENCE, BILIMORA   325 / 550  5.82   PASS
#
#                                    Course_Name  \
# 0  CERTIFICATE COURSE ON GOOGLE PRODUCTS(CCGP)
# 1  CERTIFICATE COURSE ON GOOGLE PRODUCTS(CCGP)
# 2  CERTIFICATE COURSE ON GOOGLE PRODUCTS(CCGP)
# 3  CERTIFICATE COURSE ON GOOGLE PRODUCTS(CCGP)
# 4  CERTIFICATE COURSE ON GOOGLE PRODUCTS(CCGP)
#
#    ADVANCE_WEB_TECHNOLOGY_Ext_Theory  ADVANCE_WEB_TECHNOLOGY_Ext_Practical  \
# 0                               11.0                                  22.0
# 1                                9.0                                  19.0
# 2                               16.0                                  19.0
# 3                               12.0                                  19.0
# 4                               13.0                                  19.0
#
#    ADVANCE_WEB_TECHNOLOGY_Total_Ext  ...  NETWORK_TECHNOLOGY_Int_Practical  \
# 0                              33.0  ...                                 0
# 1                              28.0  ...                                 0
# 2                              35.0  ...                                 0
# 3                              31.0  ...                                 0
# 4                              32.0  ...                                 0
#
#    NETWORK_TECHNOLOGY_Total_Int  NETWORK_TECHNOLOGY_Total_Obt  \
# 0                          36.0                          56.0
# 1                          38.0                          66.0
# 2                          40.0                          65.0
# 3                          30.0                          56.0
# 4                          33.0                          53.0
#
#    Course_Ext_Theory  Course_Ext_Practical  Course_Total_Ext  \
# 0                  0                     0              15.0
# 1                  0                     0              25.0
# 2                  0                     0              17.0
# 3                  0                     0              25.0
# 4                  0                     0              20.0
#
#    Course_Int_Theory  Course_Int_Practical  Course_Total_Int  Course_Total_Obt
# 0                  0                     0                17              32.0
# 1                  0                     0                15              40.0
# 2                  0                     0                12              29.0
# 3                  0                     0                14              39.0
# 4                  0                     0                11              31.0
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (8987, 49)

# %%
df.describe()
# Out:
#         Seat Number  ADVANCE_WEB_TECHNOLOGY_Ext_Theory  \
# count   8987.000000                        8950.000000
# mean    5520.181262                          12.612514
# std     2609.081077                           4.584711
# min     1001.000000                           1.000000
# 25%     3264.500000                           9.000000
# 50%     5513.000000                          13.000000
# 75%     7771.500000                          16.000000
# max    10042.000000                          25.000000
#
#        ADVANCE_WEB_TECHNOLOGY_Ext_Practical  ADVANCE_WEB_TECHNOLOGY_Total_Ext  \
# count                           8805.000000                       8793.000000
# mean                              18.125951                         30.813261
# std                                3.420402                          6.516300
# min                                5.000000                          9.000000
# 25%                               16.000000                         26.000000
# 50%                               18.000000                         31.000000
# 75%                               21.000000                         35.000000
# max                               25.000000                         49.000000
#
#        ADVANCE_WEB_TECHNOLOGY_Int_Theory  \
# count                        8987.000000
# mean                           17.628463
# std                             3.600709
# min                             5.000000
# 25%                            15.000000
# 50%                            18.000000
# 75%                            20.000000
# max                            25.000000
#
#        ADVANCE_WEB_TECHNOLOGY_Int_Practical  ADVANCE_WEB_TECHNOLOGY_Total_Int  \
# count                           8942.000000                       8942.000000
# mean                              19.949117                         37.603556
# std                                3.468778                          5.958057
# min                                8.000000                         16.000000
# 25%                               18.000000                         34.000000
# 50%                               20.000000                         38.000000
# 75%                               23.000000                         42.000000
# max                               25.000000                         50.000000
#
#        ADVANCE_WEB_TECHNOLOGY_Total_Obt  \
# count                       8987.000000
# mean                          67.823968
# std                           11.734305
# min                            9.000000
# 25%                           60.000000
# 50%                           68.000000
# 75%                           76.000000
# max                           99.000000
#
#        WEB_FRAMEWORK_AND_SERVICES_Ext_Theory  \
# count                            8948.000000
# mean                               13.344323
# std                                 4.612686
# min                                 1.000000
# 25%                                10.000000
# 50%                                13.000000
# 75%                                17.000000
# max                                25.000000
#
#        WEB_FRAMEWORK_AND_SERVICES_Ext_Practical  ...  \
# count                               8830.000000  ...
# mean                                  18.250057  ...
# std                                    3.169073  ...
# min                                    5.000000  ...
# 25%                                   16.000000  ...
# 50%                                   18.000000  ...
# 75%                                   20.000000  ...
# max                                   25.000000  ...
#
#        NETWORK_TECHNOLOGY_Int_Practical  NETWORK_TECHNOLOGY_Total_Int  \
# count                            8987.0                   8986.000000
# mean                                0.0                     35.912531
# std                                 0.0                      6.788770
# min                                 0.0                      9.000000
# 25%                                 0.0                     32.000000
# 50%                                 0.0                     37.000000
# 75%                                 0.0                     41.000000
# max                                 0.0                     50.000000
#
#        NETWORK_TECHNOLOGY_Total_Obt  Course_Ext_Theory  Course_Ext_Practical  \
# count                   8938.000000             8987.0                8987.0
# mean                      64.837324                0.0                   0.0
# std                       13.035321                0.0                   0.0
# min                       18.000000                0.0                   0.0
# 25%                       56.000000                0.0                   0.0
# 50%                       66.000000                0.0                   0.0
# 75%                       74.000000                0.0                   0.0
# max                       98.000000                0.0                   0.0
#
#        Course_Total_Ext  Course_Int_Theory  Course_Int_Practical  \
# count       8956.000000             8987.0                8987.0
# mean          19.973872                0.0                   0.0
# std            3.942749                0.0                   0.0
# min            3.000000                0.0                   0.0
# 25%           18.000000                0.0                   0.0
# 50%           21.000000                0.0                   0.0
# 75%           23.000000                0.0                   0.0
# max           25.000000                0.0                   0.0
#
#        Course_Total_Int  Course_Total_Obt
# count       8987.000000       8986.000000
# mean          20.071882         39.987091
# std            3.248098          6.356489
# min            6.000000         14.000000
# 25%           18.000000         36.000000
# 50%           20.000000         41.000000
# 75%           23.000000         45.000000
# max           25.000000         50.000000
#
# [8 rows x 43 columns]

# %%
df.isnull().sum()
# Out:
# Seat Number                                    0
# Name                                           0
# College Name                                   0
# Total Marks                                    0
# SGPA                                           0
# Result                                         0
# Course_Name                                    0
# ADVANCE_WEB_TECHNOLOGY_Ext_Theory             37
# ADVANCE_WEB_TECHNOLOGY_Ext_Practical         182
# ADVANCE_WEB_TECHNOLOGY_Total_Ext             194
# ADVANCE_WEB_TECHNOLOGY_Int_Theory              0
# ADVANCE_WEB_TECHNOLOGY_Int_Practical          45
# ADVANCE_WEB_TECHNOLOGY_Total_Int              45
# ADVANCE_WEB_TECHNOLOGY_Total_Obt               0
# WEB_FRAMEWORK_AND_SERVICES_Ext_Theory         39
# WEB_FRAMEWORK_AND_SERVICES_Ext_Practical     157
# WEB_FRAMEWORK_AND_SERVICES_Total_Ext         168
# WEB_FRAMEWORK_AND_SERVICES_Int_Theory          1
# WEB_FRAMEWORK_AND_SERVICES_Int_Practical      47
# WEB_FRAMEWORK_AND_SERVICES_Total_Int          47
# WEB_FRAMEWORK_AND_SERVICES_Total_Obt           1
# .NET_TECHNOLOGY_Ext_Theory                    39
# .NET_TECHNOLOGY_Ext_Practical                103
# .NET_TECHNOLOGY_Total_Ext                    113
# .NET_TECHNOLOGY_Int_Theory                     1
# .NET_TECHNOLOGY_Int_Practical                 11
# .NET_TECHNOLOGY_Total_Int                     11
# .NET_TECHNOLOGY_Total_Obt                      1
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Theory        43
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Practical    105
# LINUX_OPERATING_SYSTEM(LOS)_Total_Ext        117
# LINUX_OPERATING_SYSTEM(LOS)_Int_Theory         1
# LINUX_OPERATING_SYSTEM(LOS)_Int_Practical      8
# LINUX_OPERATING_SYSTEM(LOS)_Total_Int          9
# LINUX_OPERATING_SYSTEM(LOS)_Total_Obt          9
# NETWORK_TECHNOLOGY_Ext_Theory                  0
# NETWORK_TECHNOLOGY_Ext_Practical               0
# NETWORK_TECHNOLOGY_Total_Ext                 334
# NETWORK_TECHNOLOGY_Int_Theory                  0
# NETWORK_TECHNOLOGY_Int_Practical               0
# NETWORK_TECHNOLOGY_Total_Int                   1
# NETWORK_TECHNOLOGY_Total_Obt                  49
# Course_Ext_Theory                              0
# Course_Ext_Practical                           0
# Course_Total_Ext                              31
# Course_Int_Theory                              0
# Course_Int_Practical                           0
# Course_Total_Int                               0
# Course_Total_Obt                               1
# dtype: int64

# %%
df.dtypes
# Out:
# Seat Number                                    int64
# Name                                          object
# College Name                                  object
# Total Marks                                   object
# SGPA                                          object
# Result                                        object
# Course_Name                                   object
# ADVANCE_WEB_TECHNOLOGY_Ext_Theory            float64
# ADVANCE_WEB_TECHNOLOGY_Ext_Practical         float64
# ADVANCE_WEB_TECHNOLOGY_Total_Ext             float64
# ADVANCE_WEB_TECHNOLOGY_Int_Theory              int64
# ADVANCE_WEB_TECHNOLOGY_Int_Practical         float64
# ADVANCE_WEB_TECHNOLOGY_Total_Int             float64
# ADVANCE_WEB_TECHNOLOGY_Total_Obt               int64
# WEB_FRAMEWORK_AND_SERVICES_Ext_Theory        float64
# WEB_FRAMEWORK_AND_SERVICES_Ext_Practical     float64
# WEB_FRAMEWORK_AND_SERVICES_Total_Ext         float64
# WEB_FRAMEWORK_AND_SERVICES_Int_Theory        float64
# WEB_FRAMEWORK_AND_SERVICES_Int_Practical     float64
# WEB_FRAMEWORK_AND_SERVICES_Total_Int         float64
# WEB_FRAMEWORK_AND_SERVICES_Total_Obt         float64
# .NET_TECHNOLOGY_Ext_Theory                   float64
# .NET_TECHNOLOGY_Ext_Practical                float64
# .NET_TECHNOLOGY_Total_Ext                    float64
# .NET_TECHNOLOGY_Int_Theory                   float64
# .NET_TECHNOLOGY_Int_Practical                float64
# .NET_TECHNOLOGY_Total_Int                    float64
# .NET_TECHNOLOGY_Total_Obt                    float64
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Theory       float64
# LINUX_OPERATING_SYSTEM(LOS)_Ext_Practical    float64
# LINUX_OPERATING_SYSTEM(LOS)_Total_Ext        float64
# LINUX_OPERATING_SYSTEM(LOS)_Int_Theory       float64
# LINUX_OPERATING_SYSTEM(LOS)_Int_Practical    float64
# LINUX_OPERATING_SYSTEM(LOS)_Total_Int        float64
# LINUX_OPERATING_SYSTEM(LOS)_Total_Obt        float64
# NETWORK_TECHNOLOGY_Ext_Theory                  int64
# NETWORK_TECHNOLOGY_Ext_Practical               int64
# NETWORK_TECHNOLOGY_Total_Ext                 float64
# NETWORK_TECHNOLOGY_Int_Theory                  int64
# NETWORK_TECHNOLOGY_Int_Practical               int64
# NETWORK_TECHNOLOGY_Total_Int                 float64
# NETWORK_TECHNOLOGY_Total_Obt                 float64
# Course_Ext_Theory                              int64
# Course_Ext_Practical                           int64
# Course_Total_Ext                             float64
# Course_Int_Theory                              int64
# Course_Int_Practical                           int64
# Course_Total_Int                               int64
# Course_Total_Obt                             float64
# dtype: object

# %%
df.hist(figsize=(12,8))
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.figure(figsize=(8,6))
# ----> 2 sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
#       3 plt.show()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1693, in BlockManager.as_array(self, dtype, copy, na_value)
#    1691         arr.flags.writeable = False
#    1692 else:
# -> 1693     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1694     # The underlying data was copied within _interleave, so no need
#    1695     # to further copy if copy=True or setting na_value
#    1697 if na_value is lib.no_default:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1752, in BlockManager._interleave(self, dtype, na_value)
#    1750     else:
#    1751         arr = blk.get_values(dtype)
# -> 1752     result[rl.indexer] = arr
#    1753     itemmask[rl.indexer] = 1
#    1755 if not itemmask.all():
#
# ValueError: could not convert string to float: 'ADEP SAIKRISHNA KISHORBHAI'
